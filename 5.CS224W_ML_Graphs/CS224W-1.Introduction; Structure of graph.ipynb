# %% [markdown]
# ## CS224W 1. Introduction; Structure of graph
#
#
# ![image.png](attachment:d3a5426b-2f39-4ce5-b917-b4bd806b7f9f.png)
#
# - 해당 스터디 글은 투빅스 GNN 스터디 자료와 Stanford University의 CS224W를 참고하였습니다.

# %% [markdown]
# ### 1. Networks
#
# **Network: graph representaion with data**
#
# - 네트워크는 서로 상호작용하는 entity 간 복잡한 시스템을 설명할 수 있는 범용 언어
# - 표현하고자 하는 object를 선으로 연결함으로써 network를 만듬
# - 데이터 가용성을 고려하였을 때 다양한 도메인에서 사용될 수 있음 (web/mobile, bio, health, medical, etc.)
# - Impact : social network, drug design, AI reasoning

# %% [markdown]
# **Many types of networks**
# ![image.png](attachment:208f9cae-3e5a-4345-b5bf-cd655d9e3e57.png)

# %% [markdown]
# - 모든 네트워크는 저마다의 object가 의미하는 바가 다르며, 그들의 관계 또한 다름
# - 주어진 network를 이해하지 못하면 모델링을 할 수가 없음

# %% [markdown]
# **Ways to Analyze Networks**
#
# - Node classification
# - Link prediction
# - Community detection
# - Network similarity

# %% [markdown]
# ### 2. Structure Of Graphs
#
# **Components of a Network**
# - Objects **N** : nodes, vertices
# - Interactions **E** : links, edges
# - System **G(N,E)** : network, graph

# %% [markdown]
# **Networks or Graphs?**
#
# - Network: real system (Language : network, node, drug network)
#
# - Graph : network의 수학적 표현 (Language : graph, vertex, edges)
#
# - 둘의 경계가 모호하기 때문에 일반적으로 혼용하는 편이다.
#
# ![image.png](attachment:4583c0a7-c387-4d24-95ce-3e0c8d99f5ce.png)

# %% [markdown]
# ### 3. Choice of Network Representation
#
# **Direction of edges**
# - Undirected graph : 링크가 양방향인 그래프
#  * ex) collaborations, friendship
#
#
# - Directed graph: 링크에 특정 방향이 주어지는 그래프
#  * ex) citation/quotation, 인스타 DM, 팔로잉, 좋아요
#
#  ![image.png](attachment:fddb3df0-63b2-47f1-9fa0-b30ad6fcddcb.png)

# %% [markdown]
# **Node Degrees**
#
# - Degree(차수) : 노드에 부속되어 있는 link의 수
# - Undirected graoph의 평균 차수 : 2E/N (E: edge 개수 / N: node 개수)
#
# ![image.png](attachment:678b43d6-7d82-4121-97ba-b3cbfb360178.png)
#
# - 해당 예시에서는 $K_{A}$= 4
# - Directed의 경우 in-degree와 out-degree가 구분됨
#  * 전체 차수는 두 가지 degree의 종합이다.

# %% [markdown]
# **Complete Graph**
#
# - **Undirected graph**의 최대 edge의 개수 $E_{max} = {N(N-1) \over 2}$
# - **Complete graph** : 최대 edge개수를 가진 undirected grpah

# %% [markdown]
# **Bipartite Graph**
# - **Bipartite graph**: 서로 다른 종류의 독립된 노드들로 구성된 그래프
#  * 두 가지 노드타입 U, V로 나눌 수 있음
#  * U에 속하는 노드는 V에 속한 노드에게만 연결되고 U끼리 독립
#  * V에 속하는 노드는 U에 속한 노드에게만 연결되고 V끼리 독립

# %% [markdown]
# ### 4. Representating Graphs
#
# **Adjacency Matrix**
# - Adjacency Matrix(인접 행렬) : 그래프 연결 유무를 1과 0으로 나누어 행렬로 표시
# - Undirected의 경우 대칭으로 나타나며 Undirected는 단방향일 수 있기 때문에 대칭이 아닐 수 있음
# - 노드가 많아질 수록, 행렬의 차원이 커질 수록 **Sparse** 해진다는 단점이 있음
#
# ![image.png](attachment:946f251e-92ff-4e93-95a7-387097c6e5bd.png)

# %% [markdown]
# **Edge list**
# - Edge를 연결된 노드 쌍으로 표현한 것
#
#
# ![image.png](attachment:7aa6906d-420a-41b9-b89c-c446d2ce3fe1.png)

# %% [markdown]
# **Adjacency list**
#
# - 출발방향의 노드를 Key 값으로, 도착 노드를 Value값으로 가지는 Dictionary한 형태
# - 단방향이거나 거대한 그래프에서 효율이 좋음
# ![image.png](attachment:81ad6e82-3244-4cea-9063-458a75c48193.png)

# %% [markdown]
# **Edge Attributes**
# - Weight : edge에 weight를 줄 수 있음 (와인 추천 시 와인에 대한 평점을 edge에 weight 줄 수 있음)
# - Ranking : 짱절친, 절친, 아는 사이
# - Type : 친구, 친척, 직장동료
#
# ![image.png](attachment:9c13d190-3a99-4f8f-8842-a7a9c5f8af67.png)

# %% [markdown]
# **More types of Graph**
#
# ![image.png](attachment:abb7f69e-9396-4d09-8a99-faa1c9af62d2.png)

# %% [markdown]
# **Connectivity of Undirected Graphs**
#
# - Connected graph(Undirected) : 어떤 노드에서 출발하든지 다른 모든 노드로 도착할 수 있음
# - Disconnected graph: 최소 2개 이상의 connected graph로 구성됨
# - Bridge edge : 삭제되면 connected에서 disconnected로 바꿀 수 있는 edge
# - Articulation node: 삭제되면 connected에서 disconnected로 바꿀 수 있는 node
#
# ![image.png](attachment:9a4bcb15-8f28-49b9-92f1-fc58e7e286fc.png)

# %% [markdown]
# - Disconnected의 경우 인접행렬은 block-diagonal의 형태가 된다.
# ![image.png](attachment:b1f26ff8-8bd6-49ae-b64c-ad6c9a6a1259.png)

# %% [markdown]
# **Connectivity of Directed Graphs**
# - Strongly connected directed graph : 어떤 노드에서 출발하든지 edge 방향을 지키면서 다른 모든 노드로 도착할 수 있음
#
# - Wealky connected directed graph: 어떤 노드에서 출발하든지 edge방향을 무시한다면 다른 모든 노드로 도착할 수 있음
#
# ![image.png](attachment:4e6ed562-ff40-4e35-9394-de068925d60f.png)

# %% [markdown]
# - Strongly connected components(SCCs): 그래프에서 부분적으로 나타나는 connected subgraph
#  * SCCs 포함유무에 따라 In-component, Out-component로 분류
#
# ![image.png](attachment:50ea520f-d6b6-4d61-8a46-e7d3fb47ab92.png)
